# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("jean-pocket-measurements.csv")
df.head
# Out:
# <bound method NDFrame.head of        brand     style gender  height_front  width_front  height_back  \
# 0   3fe5003e    skinny  women          14.5         16.5         15.0
# 1   3fe5003e  straight  women          14.5         16.0         15.5
# 2   790c6eab    skinny  women          13.0         14.5         15.5
# 3   790c6eab  straight  women          13.0         14.5         14.5
# 4   26aaf627    skinny  women          13.0         14.0         14.0
# ..       ...       ...    ...           ...          ...          ...
# 75  afb94ef0  straight    men          28.0         13.0         16.7
# 76  49d2b8a1  straight  women          15.0         16.0         14.5
# 77  49d2b8a1    skinny  women          14.5         16.0         14.0
# 78  49d2b8a1  straight    men          21.0         18.5         16.0
# 79  49d2b8a1    skinny    men          21.0         19.0         16.0
#
#     width_back
# 0         13.7
# 1         13.0
# 2         13.5
# 3         13.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         80 non-null     object
#  1   style         80 non-null     object
#  2   gender        80 non-null     object
#  3   height_front  80 non-null     float64
#  4   width_front   80 non-null     float64
#  5   height_back   80 non-null     float64
#  6   width_back    80 non-null     float64
# dtypes: float64(4), object(3)
# memory usage: 4.5+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        brand     style gender  height_front  width_front  height_back  \
# 0   3fe5003e    skinny  women          14.5         16.5         15.0
# 1   3fe5003e  straight  women          14.5         16.0         15.5
# 2   790c6eab    skinny  women          13.0         14.5         15.5
# 3   790c6eab  straight  women          13.0         14.5         14.5
# 4   26aaf627    skinny  women          13.0         14.0         14.0
# ..       ...       ...    ...           ...          ...          ...
# 75  afb94ef0  straight    men          28.0         13.0         16.7
# 76  49d2b8a1  straight  women          15.0         16.0         14.5
# 77  49d2b8a1    skinny  women          14.5         16.0         14.0
# 78  49d2b8a1  straight    men          21.0         18.5         16.0
# 79  49d2b8a1    skinny    men          21.0         19.0         16.0
#
#     width_back
# 0         13.7
# 1         13.0
# 2         13.5
# 3         13.0
# ...

# %%
df.isnull().sum()
# Out:
# brand           0
# style           0
# gender          0
# height_front    0
# width_front     0
# height_back     0
# width_back      0
# dtype: int64

# %%
df['brand'].unique()
df['brand'].value_counts()
# Out:
# brand
# 3fe5003e    4
# 790c6eab    4
# 26aaf627    4
# ba56feb3    4
# 7398d4c6    4
# 0d014017    4
# 7b34fdbd    4
# 9cc5821d    4
# 59133a58    4
# 70b9ccb6    4
# 1428e336    4
# b144fa06    4
# dfc9a4ab    4
# ce93e0bd    4
# 2abe57bc    4
# 466b98ca    4
# 57ed7595    4
# 33147c75    4
# afb94ef0    4
# 49d2b8a1    4
# Name: count, dtype: int64

# %%
df.rename(columns={'height_front':'height'}, inplace=True)
df.rename(columns={'width_front' : 'width'}, inplace=True)
df.head()
# Out:
#       brand     style gender  height  width  height_back  width_back
# 0  3fe5003e    skinny  women    14.5   16.5         15.0        13.7
# 1  3fe5003e  straight  women    14.5   16.0         15.5        13.0
# 2  790c6eab    skinny  women    13.0   14.5         15.5        13.5
# 3  790c6eab  straight  women    13.0   14.5         14.5        13.0
# 4  26aaf627    skinny  women    13.0   14.0         14.0        14.2

# %%
df['height'].sum
df['height'].mean
# Out:
# <bound method Series.mean of 0     14.5
# 1     14.5
# 2     13.0
# 3     13.0
# 4     13.0
#       ...
# 75    28.0
# 76    15.0
# 77    14.5
# 78    21.0
# 79    21.0
# Name: height, Length: 80, dtype: float64>

# %%
df.dropna()
# Out:
#        brand     style gender  height  width  height_back  width_back
# 0   3fe5003e    skinny  women    14.5   16.5         15.0        13.7
# 1   3fe5003e  straight  women    14.5   16.0         15.5        13.0
# 2   790c6eab    skinny  women    13.0   14.5         15.5        13.5
# 3   790c6eab  straight  women    13.0   14.5         14.5        13.0
# 4   26aaf627    skinny  women    13.0   14.0         14.0        14.2
# ..       ...       ...    ...     ...    ...          ...         ...
# 75  afb94ef0  straight    men    28.0   13.0         16.7        14.5
# 76  49d2b8a1  straight  women    15.0   16.0         14.5        13.5
# 77  49d2b8a1    skinny  women    14.5   16.0         14.0        14.0
# 78  49d2b8a1  straight    men    21.0   18.5         16.0        13.0
# 79  49d2b8a1    skinny    men    21.0   19.0         16.0        14.0
#
# [80 rows x 7 columns]

# %%
df.values
# Out:
# array([['3fe5003e', 'skinny', 'women', 14.5, 16.5, 15.0, 13.7],
#        ['3fe5003e', 'straight', 'women', 14.5, 16.0, 15.5, 13.0],
#        ['790c6eab', 'skinny', 'women', 13.0, 14.5, 15.5, 13.5],
#        ['790c6eab', 'straight', 'women', 13.0, 14.5, 14.5, 13.0],
#        ['26aaf627', 'skinny', 'women', 13.0, 14.0, 14.0, 14.2],
#        ['26aaf627', 'straight', 'women', 15.5, 16.5, 14.5, 12.5],
#        ['ba56feb3', 'skinny', 'women', 12.0, 14.5, 16.5, 13.0],
#        ['ba56feb3', 'straight', 'women', 14.0, 15.5, 15.0, 14.0],
#        ['7398d4c6', 'skinny', 'women', 13.0, 13.5, 16.0, 14.5],
#        ['7398d4c6', 'straight', 'women', 15.0, 15.5, 14.5, 13.0],
#        ['0d014017', 'skinny', 'women', 12.5, 15.0, 14.5, 12.0],
#        ['0d014017', 'straight', 'women', 12.2, 17.0, 15.5, 12.5],
#        ['7b34fdbd', 'skinny', 'women', 13.7, 18.5, 14.5, 14.0],
#        ['7b34fdbd', 'straight', 'women', 13.5, 17.0, 15.0, 14.5],
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df['height'] = pd.to_numeric(df['height'], errors='coerce')
df['width'] = pd.to_numeric(df['width'], errors='coerce')

df = df.dropna(subset=['height', 'width'])

df['height'].hist()
plt.show()

plt.scatter(df['height'], df['width'])
plt.show() 

numeric_df = df.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
print(df.dtypes)
numeric_df=df.select_dtypes(include=['float64','int64'])
corr=numeric_df.corr()
print(corr)
# Out:
# brand           object
# style           object
# gender          object
# height         float64
# width          float64
# height_back    float64
# width_back     float64
# dtype: object
#                height     width  height_back  width_back
# height       1.000000  0.379843     0.482482    0.156709
# width        0.379843  1.000000     0.193253    0.244814
# height_back  0.482482  0.193253     1.000000    0.389539
# width_back   0.156709  0.244814     0.389539    1.000000

# %%
df.rename(columns={'height_back':'heightb'}, inplace=True)
df.rename(columns={'width_back' : 'widthb'}, inplace=True)
df.head()
# Out:
#       brand     style gender  height  width  heightb  widthb
# 0  3fe5003e    skinny  women    14.5   16.5     15.0    13.7
# 1  3fe5003e  straight  women    14.5   16.0     15.5    13.0
# 2  790c6eab    skinny  women    13.0   14.5     15.5    13.5
# 3  790c6eab  straight  women    13.0   14.5     14.5    13.0
# 4  26aaf627    skinny  women    13.0   14.0     14.0    14.2

# %%
df.groupby('brand')['height'].mean()
df.groupby('style')['width'].sum()
# Out:
# style
# skinny      622.9
# straight    639.3
# Name: width, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score 

X = df[['height', 'width']] 
y = df['brand']              


label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)


model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.0625
